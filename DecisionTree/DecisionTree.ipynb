# %%
import pandas as pd

data = pd.read_csv("simpsons.csv")

data = data.drop("Unnamed: 0", axis=1)
x = data.drop("gender", axis=1)
y = data["gender"]

x.shape, y.shape
# Out:
# ((9, 3), (9,))

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(criterion='entropy')
dtc.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn import tree

tree.plot_tree(dtc, feature_names=x.columns)
# Out:
# [Text(200.88000000000002, 181.2, 'weight <= 165.0\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]'),
#  Text(133.92000000000002, 108.72, 'hair_length <= 3.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(66.96000000000001, 36.23999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(200.88000000000002, 36.23999999999998, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(267.84000000000003, 108.72, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]')]
